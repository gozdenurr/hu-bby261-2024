# %% [markdown]
# <a href="https://colab.research.google.com/github/gozdenurr/hu-bby261-2024/blob/main/HealthFoodVeriSeti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
veriSeti = pd.read_csv('health.csv')
yemek= veriSeti["Food"]
kalori= veriSeti["Calories"]
plt.figure(figsize=(20, 7))
plt.xlabel('yemek')
plt.ylabel('kalori')
plt.bar(yemek, kalori, color="g")
x_sutun = ["yemek"]
y_sutun = ["kalori"]
plt.title('kalorilerine göre yemek listesi')
plt.xticks(rotation=90)
plt.show()
